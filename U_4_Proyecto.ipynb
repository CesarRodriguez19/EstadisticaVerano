# %% [markdown]
# <a href="https://colab.research.google.com/github/CesarRodriguez19/EstadisticaVerano/blob/main/U_4_Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/CesarRodriguez19/EstadisticaVerano/refs/heads/main/diabetes.csv")

df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.columns = ["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin",
              "BMI","DiabetesPedigreeFuntion","Age","Outcome"]
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFuntion  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 2                      0.672   32        1
# 3                      0.167   21        0
# 4                      2.288   33        1
# ..                       ...  ...      ...
# 763                    0.171   63        0
# 764                    0.340   27        0
# 765                    0.245   30        0
# 766                    0.349   47        1
# 767                    0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ##Eliminar datos atipicos

# %%
from matplotlib import pyplot as plt
df['Glucose'].plot(kind='hist', bins=20, title='Glucose')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df=df[df["Glucose"]>0]
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFuntion  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 2                      0.672   32        1
# 3                      0.167   21        0
# 4                      2.288   33        1
# ..                       ...  ...      ...
# 763                    0.171   63        0
# 764                    0.340   27        0
# 765                    0.245   30        0
# 766                    0.349   47        1
# 767                    0.315   23        0
#
# [763 rows x 9 columns]

# %%
from matplotlib import pyplot as plt
df['Glucose'].plot(kind='hist', bins=20, title='Glucose')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['BloodPressure'].plot(kind='hist', bins=20, title='BloodPressure')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df=df[df["BloodPressure"]>0]
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFuntion  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 2                      0.672   32        1
# 3                      0.167   21        0
# 4                      2.288   33        1
# ..                       ...  ...      ...
# 763                    0.171   63        0
# 764                    0.340   27        0
# 765                    0.245   30        0
# 766                    0.349   47        1
# 767                    0.315   23        0
#
# [728 rows x 9 columns]

# %%
from matplotlib import pyplot as plt
df['BloodPressure'].plot(kind='hist', bins=20, title='BloodPressure')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['SkinThickness'].plot(kind='hist', bins=20, title='SkinThickness')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df=df[df["SkinThickness"]>0]
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFuntion  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 3                      0.167   21        0
# 4                      2.288   33        1
# 6                      0.248   26        1
# ..                       ...  ...      ...
# 761                    0.403   43        1
# 763                    0.171   63        0
# 764                    0.340   27        0
# 765                    0.245   30        0
# 767                    0.315   23        0
#
# [534 rows x 9 columns]

# %%
from matplotlib import pyplot as plt
df['SkinThickness'].plot(kind='hist', bins=20, title='SkinThickness')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['BMI'].plot(kind='hist', bins=20, title='BMI')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df=df[df["BMI"]>0]
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFuntion  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 3                      0.167   21        0
# 4                      2.288   33        1
# 6                      0.248   26        1
# ..                       ...  ...      ...
# 761                    0.403   43        1
# 763                    0.171   63        0
# 764                    0.340   27        0
# 765                    0.245   30        0
# 767                    0.315   23        0
#
# [532 rows x 9 columns]

# %%
from matplotlib import pyplot as plt
df['BMI'].plot(kind='hist', bins=20, title='BMI')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['DiabetesPedigreeFuntion'].plot(kind='hist', bins=20, title='DiabetesPedigreeFuntion')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFuntion  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 3                      0.167   21        0
# 4                      2.288   33        1
# 6                      0.248   26        1
# ..                       ...  ...      ...
# 761                    0.403   43        1
# 763                    0.171   63        0
# 764                    0.340   27        0
# 765                    0.245   30        0
# 767                    0.315   23        0
#
# [532 rows x 9 columns]

# %% [markdown]
# ##Pregnancies

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Pregnancies ~ C(Outcome)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                df       sum_sq     mean_sq          F        PR(>F)
# C(Outcome)    1.0   371.622026  371.622026  36.118012  3.456974e-09
# Residual    530.0  5453.225718   10.289105        NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Pregnancies'], groups=df['Outcome'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Diabetes", xlabel="Embarazo")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================
# group1 group2 meandiff p-adj lower upper  reject
# ------------------------------------------------
#      0      1   1.7738   0.0 1.194 2.3536   True
# ------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# ##Glucose

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("	Glucose ~ C(Outcome)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                df         sum_sq        mean_sq           F        PR(>F)
# C(Outcome)    1.0  129417.111731  129417.111731  180.100712  1.473834e-35
# Residual    530.0  380848.407066     718.581900         NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Glucose'], groups=df['Outcome'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Diabetes", xlabel="Embarazo")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1  33.1017   0.0 28.2563 37.9472   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# ##BloodPressure

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("	BloodPressure ~ C(Outcome)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                df        sum_sq      mean_sq          F    PR(>F)
# C(Outcome)    1.0   2707.560181  2707.560181  18.453969  0.000021
# Residual    530.0  77761.422901   146.719666        NaN       NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['BloodPressure'], groups=df['Outcome'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Diabetes", xlabel="Embarazo")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#      0      1   4.7879   0.0 2.5984 6.9774   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# ##SkinThickness

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("SkinThickness	~ C(Outcome)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                df        sum_sq      mean_sq         F        PR(>F)
# C(Outcome)    1.0   3820.288812  3820.288812  36.82104  2.466891e-09
# Residual    530.0  54989.025097   103.752878       NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['SkinThickness'], groups=df['Outcome'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Diabetes", xlabel="Embarazo")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#      0      1   5.6873   0.0 3.8461 7.5284   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# ##insilin

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Insulin~ C(Outcome)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                df        sum_sq        mean_sq          F        PR(>F)
# C(Outcome)    1.0  3.617983e+05  361798.267844  24.991644  7.837566e-07
# Residual    530.0  7.672688e+06   14476.769178        NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Insulin'], groups=df['Outcome'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Diabetes", xlabel="Embarazo")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1  55.3463   0.0 33.5976 77.0949   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# ##BMI

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("BMI~ C(Outcome)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                df        sum_sq      mean_sq          F        PR(>F)
# C(Outcome)    1.0   2276.448945  2276.448945  52.764205  1.351522e-12
# Residual    530.0  22866.220228    43.143812        NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['BMI'], groups=df['Outcome'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Diabetes", xlabel="Embarazo")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#      0      1   4.3902   0.0 3.2029 5.5775   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# ##DiabetesPedigreeFuntion

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("DiabetesPedigreeFuntion~ C(Outcome)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                df     sum_sq   mean_sq          F        PR(>F)
# C(Outcome)    1.0   3.424340  3.424340  30.445319  5.378897e-08
# Residual    530.0  59.611796  0.112475        NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['DiabetesPedigreeFuntion'], groups=df['Outcome'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Diabetes", xlabel="Embarazo")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#      0      1   0.1703   0.0 0.1097 0.2309   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# ##Age

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

modelo_lineal = ols("Age~ C(Outcome)", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                df        sum_sq      mean_sq          F        PR(>F)
# C(Outcome)    1.0   6105.693265  6105.693265  58.422083  9.990069e-14
# Residual    530.0  55390.312374   104.510023        NaN           NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Age'], groups=df['Outcome'],
                          alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Diabetes", xlabel="Embarazo")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================
# group1 group2 meandiff p-adj lower upper  reject
# ------------------------------------------------
#      0      1   7.1899   0.0 5.342 9.0378   True
# ------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# ##MAPA DE CALOR

# %%
import seaborn as sns
import matplotlib.pyplot as plt
matriz_de_correlacion=df.corr()
plt.figure(figsize=(10,10),dpi=100)
sns.heatmap(
    matriz_de_correlacion,#LO QUE VA A GRAFICAR
    annot=True,#SE MUESTRAN LOS VALORES EN LAS CELDAS
    fmt="0.2f",#0.2f SIGNIFICA "DOS DECIMALES"
    cmap="coolwarm",#PALETA DE COLORES
    square=True,#FORZA CUADRADOS
    linewidths=0.5,#GROSOR DE LINEAS
    cbar_kws={"shrink":0.8},#TAMAÑO BARRA LATERAL
    center=0
)
plt.title("Mapa de calor para matriz de correlacion", fontsize=20),
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=10)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5]),
#  [Text(0, 0.5, 'Pregnancies'),
#   Text(0, 1.5, 'Glucose'),
#   Text(0, 2.5, 'BloodPressure'),
#   Text(0, 3.5, 'SkinThickness'),
#   Text(0, 4.5, 'Insulin'),
#   Text(0, 5.5, 'BMI'),
#   Text(0, 6.5, 'DiabetesPedigreeFuntion'),
#   Text(0, 7.5, 'Age'),
#   Text(0, 8.5, 'Outcome')])

# %%
#En nuestro mapa de calor utilizamos Age=y y Glucose=x,

# %% [markdown]
# ## X,Y

# %%
x = df["Glucose"]
y = df["Age"]


#2 Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize = (5, 5), dpi = 100)
plt.scatter(x, y, label = "DIABETES", color = 'green')
plt.xlabel("Pregnancies") # nombrar eje x
plt.ylabel("Outcome") # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)
plt.legend()#APARECE LO QUE INDICA EL PUNTO
plt.grid()#APARECEN LOS CUADRITOS EN LA TABLA

#3¿Los datos soportan la suposición de linealidad?

#SI

#4 Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, _ = pearsonr(x, y)
print(f'Coeficiente de correlación: {r: 0.4f}\n')



# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)

plt.plot(x, yc, color = 'black', linestyle = '--')



# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')



# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')


# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales = modelo.resid
plt.figure()
plt.title("Residuales", fontsize = 10)
plt.scatter(x, residuales, color = 'purple')
plt.xlabel("Pregnancies")
plt.ylabel("Age")
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.grid()#APARECEN LOS CUADRITOS EN LA TABLA


# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')



# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el
# resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')



# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno

#print(f'para x = 0.5 y = {modelo.predict([1, 0.5])}')
#print(f'para x = 1.5, y = {modelo.predict([1, 1.5])}')
#print(f'para x = 2.0 y = {modelo.predict([1, 2.0])}\n')
#print(modelo.get_prediction([1, 4]).summary_frame(alpha = 0.05))


# 12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols("Age ~ Glucose", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# Coeficiente de correlación:  0.2789
#
# Coeficiente de determinación:  0.0778
#
# Intervalo de confianza para b1 de  95%
#  0.0684 < b1 <  0.1253
#
# valor-p de Shapiro:  0.0000
#
# valor_p de Breusch-Pagan:  0.0008
#              df        sum_sq      mean_sq          F        PR(>F)
# Glucose     1.0   4783.723554  4783.723554  44.705898  5.820400e-11
# Residual  530.0  56712.282085   107.004306        NaN           NaN

# %%
#CONCLUSION:
#

# %% [markdown]
# ## 2 VARIABLES X

# %%
x = df[["Glucose", "BMI",]]
y = df["Age"]


#2 Realice un diagrama de dispersión para estos datos.
#import matplotlib.pyplot as plt
#plt.figure(figsize = (5, 5), dpi = 100)
#plt.scatter(x, y, label = "tension_arteria", color = 'green')
#plt.xlabel("Session_Duration") # nombrar eje x
#plt.ylabel("Calories_Burned") # nombrar eje y
#plt.gca().spines[["top","right"]].set_visible(False)
#plt.legend()#APARECE LO QUE INDICA EL PUNTO
#plt.grid()#APARECEN LOS CUADRITOS EN LA TABLA

#3¿Los datos soportan la suposición de linealidad?

#SI

#4 Calcule el coeficiente de correlación e interprete el resultado.
#from scipy.stats import pearsonr
#r, _ = pearsonr(x, y)
#print(f'Coeficiente de correlación: {r: 0.4f}\n')



# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)
plt.figure()
#plt.plot(y, y, color = 'black', linestyle = '--')



# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')



# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')


# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales = modelo.resid
plt.scatter(y, yc, color = 'purple')
plt.xlabel("Session_Duration")
plt.ylabel("Calories_Burned")
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.grid()#APARECEN LOS CUADRITOS EN LA TABLA


# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')



# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el
# resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')



# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno

#print(f'para x1 = 0.5, x2 =3, x3=34 y = {modelo.predict([1, 0.5, 3, 34])}')
#print(f'para x1 = 1.5, x2 =2, x3=50 y = {modelo.predict([1, 1.5, 2, 50])}')
#print(f'para x1 = 2.0, x2 =4, x3=40 y = {modelo.predict([1, 2.0, 4, 40])}\n')
#print(modelo.get_prediction([1, 4]).summary_frame(alpha = 0.05))


# 12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols("Age ~ Glucose + BMI", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# Coeficiente de determinación:  0.0778
#
# Intervalo de confianza para b1 de  95%
#  0.0670 < b1 <  0.1258
#
# valor-p de Shapiro:  0.0000
#
# valor_p de Breusch-Pagan:  0.0020
#              df        sum_sq      mean_sq          F        PR(>F)
# Glucose     1.0   4783.723554  4783.723554  44.622603  6.063383e-11
# BMI         1.0      1.341681     1.341681   0.012515  9.109678e-01
# Residual  529.0  56710.940405   107.204046        NaN           NaN

# %%
#CONCLUSION:
#

# %% [markdown]
# ## 3 variables x

# %%
x = df[["Glucose", "BMI","DiabetesPedigreeFuntion"]]
y = df["Age"]


#2 Realice un diagrama de dispersión para estos datos.
#import matplotlib.pyplot as plt
#plt.figure(figsize = (5, 5), dpi = 100)
#plt.scatter(x, y, label = "tension_arteria", color = 'green')
#plt.xlabel("Session_Duration") # nombrar eje x
#plt.ylabel("Calories_Burned") # nombrar eje y
#plt.gca().spines[["top","right"]].set_visible(False)
#plt.legend()#APARECE LO QUE INDICA EL PUNTO
#plt.grid()#APARECEN LOS CUADRITOS EN LA TABLA

#3¿Los datos soportan la suposición de linealidad?

#SI

#4 Calcule el coeficiente de correlación e interprete el resultado.
#from scipy.stats import pearsonr
#r, _ = pearsonr(x, y)
#print(f'Coeficiente de correlación: {r: 0.4f}\n')



# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)
plt.figure()
#plt.plot(y, y, color = 'black', linestyle = '--')



# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')



# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')


# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales = modelo.resid
plt.scatter(y, yc, color = 'purple')
plt.xlabel("Session_Duration")
plt.ylabel("Calories_Burned")
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.grid()#APARECEN LOS CUADRITOS EN LA TABLA


# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')



# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el
# resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')



# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno

#print(f'para x1 = 0.5, x2 =3, x3=34 y = {modelo.predict([1, 0.5, 3, 34])}')
#print(f'para x1 = 1.5, x2 =2, x3=50 y = {modelo.predict([1, 1.5, 2, 50])}')
#print(f'para x1 = 2.0, x2 =4, x3=40 y = {modelo.predict([1, 2.0, 4, 40])}\n')
#print(modelo.get_prediction([1, 4]).summary_frame(alpha = 0.05))


# 12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols("Age ~ Glucose + BMI + DiabetesPedigreeFuntion", data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# Coeficiente de determinación:  0.0785
#
# Intervalo de confianza para b1 de  95%
#  0.0655 < b1 <  0.1249
#
# valor-p de Shapiro:  0.0000
#
# valor_p de Breusch-Pagan:  0.0054
#                             df        sum_sq      mean_sq          F  \
# Glucose                    1.0   4783.723554  4783.723554  44.569416
# BMI                        1.0      1.341681     1.341681   0.012500
# DiabetesPedigreeFuntion    1.0     39.656054    39.656054   0.369471
# Residual                 528.0  56671.284351   107.331978        NaN
#
#                                PR(>F)
# Glucose                  6.227580e-11
# BMI                      9.110208e-01
# DiabetesPedigreeFuntion  5.435541e-01
# Residual                          NaN

# %%
# CONCLUSION:
#
