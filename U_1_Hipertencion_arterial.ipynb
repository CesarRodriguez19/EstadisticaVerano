# %% [markdown]
# <a href="https://colab.research.google.com/github/CesarRodriguez19/EstadisticaVerano/blob/main/U_1_Hipertencion_arterial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_csv ("https://raw.githubusercontent.com/CesarRodriguez19/EstadisticaVerano/refs/heads/main/Hipertension_Arterial_Mexico.csv")
df
# Out:
#             FOLIO_I  sexo  edad  concentracion_hemoglobina  \
# 0     2022_01001004     2    41                       14.2
# 1     2022_01001009     2    65                       14.1
# 2     2022_01001012     2    68                       14.2
# 3     2022_01001013     1    35                       15.7
# 4     2022_01001015     2    65                       12.7
# ...             ...   ...   ...                        ...
# 4358  2022_32056019     2    62                       14.2
# 4359  2022_32056024     1    39                       14.2
# 4360  2022_32056026     2    69                       15.9
# 4361  2022_32056029     1    67                       17.6
# 4362  2022_32056030     2    56                       14.2
#
#       temperatura_ambiente  valor_acido_urico  valor_albumina  \
# 0                       22                4.8             4.0
# 1                        9                4.4             3.8
# 2                       22                4.8             4.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4363 entries, 0 to 4362
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   FOLIO_I                           4363 non-null   object
#  1   sexo                              4363 non-null   int64
#  2   edad                              4363 non-null   int64
#  3   concentracion_hemoglobina         4363 non-null   float64
#  4   temperatura_ambiente              4363 non-null   int64
#  5   valor_acido_urico                 4363 non-null   float64
#  6   valor_albumina                    4363 non-null   float64
#  7   valor_colesterol_hdl              4363 non-null   int64
#  8   valor_colesterol_ldl              4363 non-null   float64
#  9   valor_colesterol_total            4363 non-null   int64
#  10  valor_creatina                    4363 non-null   float64
# ...

# %%
df=df.drop(columns=["FOLIO_I"])
df
# Out:
#       sexo  edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0        2    41                       14.2                    22
# 1        2    65                       14.1                     9
# 2        2    68                       14.2                    22
# 3        1    35                       15.7                    11
# 4        2    65                       12.7                     7
# ...    ...   ...                        ...                   ...
# 4358     2    62                       14.2                    22
# 4359     1    39                       14.2                    22
# 4360     2    69                       15.9                    11
# 4361     1    67                       17.6                    14
# 4362     2    56                       14.2                    22
#
#       valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0                   4.8             4.0                    34
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
matriz_de_correlacion=df.corr()
plt.figure(figsize=(20,20),dpi=100)
sns.heatmap(matriz_de_correlacion,
            annot=True,fmt="0.2f",
            cmap="coolwarm",
            square=True,
            linewidths=0.5,
            cbar_kws={"shrink":0.8},
            center=0)
plt.title("MAPA DE COLOR PARA MATRIZ DE CORRELACION",fontsize=20)
plt.xticks(rotation=45,ha="right")
plt.yticks(rotation=0)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5, 31.5, 32.5,
#         33.5, 34.5]),
#  [Text(0, 0.5, 'sexo'),
#   Text(0, 1.5, 'edad'),
#   Text(0, 2.5, 'concentracion_hemoglobina'),
#   Text(0, 3.5, 'temperatura_ambiente'),
#   Text(0, 4.5, 'valor_acido_urico'),
#   Text(0, 5.5, 'valor_albumina'),
#   Text(0, 6.5, 'valor_colesterol_hdl'),
#   Text(0, 7.5, 'valor_colesterol_ldl'),
#   Text(0, 8.5, 'valor_colesterol_total'),
#   Text(0, 9.5, 'valor_creatina'),
#   Text(0, 10.5, 'resultado_glucosa'),
#   Text(0, 11.5, 'valor_insulina'),
#   Text(0, 12.5, 'valor_trigliceridos'),
#   Text(0, 13.5, 'resultado_glucosa_promedio'),
#   Text(0, 14.5, 'valor_hemoglobina_glucosilada'),
#   Text(0, 15.5, 'valor_ferritina'),
#   Text(0, 16.5, 'valor_folato'),
#   Text(0, 17.5, 'valor_homocisteina'),
# ...

# %%
df["tension_arterial"].hist(bins=50)
# Out:
# <Axes: >

# %%
df["edad"].hist(bins=50)
# Out:
# <Axes: >

# %%
df=df[df["tension_arterial"] != 0 ]
df
# Out:
#       sexo  edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0        2    41                       14.2                    22
# 1        2    65                       14.1                     9
# 2        2    68                       14.2                    22
# 3        1    35                       15.7                    11
# 4        2    65                       12.7                     7
# ...    ...   ...                        ...                   ...
# 4358     2    62                       14.2                    22
# 4359     1    39                       14.2                    22
# 4360     2    69                       15.9                    11
# 4361     1    67                       17.6                    14
# 4362     2    56                       14.2                    22
#
#       valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0                   4.8             4.0                    34
# ...

# %%
x=df["edad"]
y=df["tension_arterial"]


#Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5),dpi=70)
plt.scatter(x,y ,label="tension_arterial",color="blue")
plt.title("Grafico de hipertension")
plt.xlabel("edad")
plt.ylabel("tension_arterial")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)

#3 si soporta la suposicion de linealidad paresen segir la tendecina
#Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r,_=pearsonr(x,y)

print("coeficiente de  correlacion=",r)

#Calcule el coeficiente de determinación e interprete el resultado.
print("coeficiente de determinacion=",r**2)

#Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
#dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
yc=modelo.predict(x_constante)
plt.plot(x,yc,color="red")

#intervalo de confianza
print("Intervalo de confianza",modelo.conf_int(0.05))

#calculo residuales
residuales=y-yc
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5),dpi=70)
plt.scatter(x,residuales,label="tension_arterial",color="blue")
plt.axhline(y=0,color="red",linestyle="--")
plt.title("Grafico de hipertension")
plt.xlabel("edad")
plt.ylabel("tension_arterial")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)

#shapiro
from scipy.stats import shapiro
estadistico_shapiro,valor_p_shapiro=shapiro(residuales)
print(f"estadistico_shapiro={estadistico_shapiro}")
print(f"valor_p_shapiro={valor_p_shapiro}")

#broush pagan
from statsmodels.stats.api import het_breuschpagan
_,valor_p_bp,_,_=het_breuschpagan(residuales,x_constante)
print(f"valor_p_bp={valor_p_bp}")

#11 la recta de regresión para interpolar dos valores y extrapolar uno
print("x=2,y=",modelo.predict([1,2]))
print("x=4,y=",modelo.predict([1,4]))
print("x=10,y=",modelo.predict([1,10]))

#tabla anova
from statsmodels.formula.api import ols
modelo_anova=ols("tension_arterial~edad", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_anova)
print(tabla_anova)
# Out:
# coeficiente de  correlacion= 0.3854603979291315
# coeficiente de determinacion= 0.1485797183716844
# Intervalo de confianza                0           1
# const  97.047529  100.865243
# edad    0.502519    0.579685
# estadistico_shapiro=0.9769111647542179
# valor_p_shapiro=5.897655284089539e-26
# valor_p_bp=1.378862112360004e-33
# x=2,y= [100.03859087]
# x=4,y= [101.12079556]
# x=10,y= [104.36740963]
#               df        sum_sq        mean_sq           F         PR(>F)
# edad         1.0  2.648644e+05  264864.431816  755.969001  1.544912e-153
# Residual  4332.0  1.517777e+06     350.364144         NaN            NaN

# %%
df["segundamedicion_cintura"].hist(bins=50)
# Out:
# <Axes: >

# %%
df=df[df["segundamedicion_cintura"] != 0 ]
df
df["segundamedicion_cintura"].hist(bins=50)
# Out:
# <Axes: >

# %%
x=df[["edad","segundamedicion_cintura"]]
y=df["tension_arterial"]

import matplotlib.pyplot as plt



#3 si soporta la suposicion de linealidad paresen segir la tendecina
#Calcule el coeficiente de correlación e interprete el resultado.


#Calcule el coeficiente de determinación e interprete el resultado.
print("coeficiente de determinacion=",r**2)

#Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
#dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
yc=modelo.predict(x_constante)
plt.plot(x,yc,color="red")

#intervalo de confianza
print("Intervalo de confianza",modelo.conf_int(0.05))

#calculo residuales
residuales=y-yc
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10),dpi=70)
plt.scatter(y,yc,color="blue")
#plt.axhline(y=0,color="red",linestyle="--")
plt.title("Grafico de hipertension")
plt.xlabel("edad")
plt.ylabel("tension_arterial")
plt.legend()
plt.grid()
plt.gca().spines[["top","right"]].set_visible(False)

#shapiro
from scipy.stats import shapiro
estadistico_shapiro,valor_p_shapiro=shapiro(residuales)
print(f"estadistico_shapiro={estadistico_shapiro}")
print(f"valor_p_shapiro={valor_p_shapiro}")

#broush pagan
from statsmodels.stats.api import het_breuschpagan
_,valor_p_bp,_,_=het_breuschpagan(residuales,x_constante)
print(f"valor_p_bp={valor_p_bp}")

#11 la recta de regresión para interpolar dos valores y extrapolar uno
#print("x=2,y=",modelo.predict([1,2]))
#print("x=4,y=",modelo.predict([1,4]))
#print("x=10,y=",modelo.predict([1,10]))

#tabla anova
from statsmodels.formula.api import ols
modelo_anova=ols("tension_arterial~edad+segundamedicion_cintura", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_anova)
print(tabla_anova)
# Out:
# coeficiente de determinacion= 0.1485797183716844
# Intervalo de confianza                                  0           1
# const                    79.421401  121.195872
# edad                     -0.096949    0.413090
# segundamedicion_cintura   0.143967    0.378484
# estadistico_shapiro=0.9830746172793073
# valor_p_shapiro=1.8877774885299705e-08
# valor_p_bp=0.788265004887809
#                             df         sum_sq      mean_sq          F  \
# edad                       1.0     509.779865   509.779865   1.051053
# segundamedicion_cintura    1.0    9272.922904  9272.922904  19.118713
# Residual                 861.0  417600.629407   485.018153        NaN
#
#                            PR(>F)
# edad                     0.305553
# segundamedicion_cintura  0.000014
# Residual                      NaN
# ...
